# %% [markdown]
# #### Based on the github repo: https://github.com/pcm-dpc/COVID-19

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/nadeem

# %%
DF = pd.read_csv('/Users/nadeem/GitHub/COVID-19/dati-regioni/dpc-covid19-ita-regioni.csv')

# %%
DF.describe()
# Out:
#        codice_regione         lat        long  ricoverati_con_sintomi  \
# count      336.000000  336.000000  336.000000              336.000000
# mean        10.190476   43.036808   12.214635               73.940476
# std          5.803707    2.509738    2.646237              312.596821
# min          1.000000   38.109228    7.320149                0.000000
# 25%          5.000000   41.125596   11.121231                0.000000
# 50%         10.000000   43.616760   12.388247                3.000000
# 75%         15.000000   45.434905   13.768136               18.000000
# max         20.000000   46.499335   16.867367             3319.000000
#
#        terapia_intensiva  totale_ospedalizzati  isolamento_domiciliare  \
# count         336.000000            336.000000              336.000000
# mean           14.261905             88.205357               51.425595
# std            53.771461            365.383874              135.565704
# ...

# %%
DF.columns
# Out:
# Index(['data', 'stato', 'codice_regione', 'denominazione_regione', 'lat',
#        'long', 'ricoverati_con_sintomi', 'terapia_intensiva',
#        'totale_ospedalizzati', 'isolamento_domiciliare',
#        'totale_attualmente_positivi', 'nuovi_attualmente_positivi',
#        'dimessi_guariti', 'deceduti', 'totale_casi', 'tamponi'],
#       dtype='object')

# %%
ItRegionHeader = pd.read_csv('/Users/nadeem/Downloads/Italy_region_description.csv')

# %%
ItRegionHeader
# Out:
#                      Field name  \
# 0                          date
# 1                         state
# 2                codice_regione
# 3         denominazione_regione
# 4                           lat
# 5                          long
# 6        ricoverati_con_sintomi
# 7                intensive care
# 8          totale_ospedalizzati
# 9        isolamento_domiciliare
# 10  totale_attualmente_positivi
# 11   nuovi_attualmente_positivi
# 12              dimessi_guariti
# 13                     deceased
# 14                  totale_casi
# 15                        swabs
#
#                                           Description  \
# 0                             Date of the information
# 1                                     Reference state
# 2                            Region Code (ISTAT 2019)
# 3                                 Region denomination
# 4                                            Latitude
# 5                                           Longitude
# ...

# %%
DF.plot.scatter(x='lat',y='long')

# %%
DF.deceduti.idxmax()
# Out:
# 324

# %%
DF.iloc[324].devaccounts
# Out:
# data                           2020-03-10 18:00:00
# stato                                          ITA
# codice_regione                                   3
# denominazione_regione                    Lombardia
# lat                                        45.4668
# long                                       9.19035
# ricoverati_con_sintomi                        3319
# terapia_intensiva                              466
# totale_ospedalizzati                          3785
# isolamento_domiciliare                         642
# totale_attualmente_positivi                   4427
# nuovi_attualmente_positivi                     -63
# dimessi_guariti                                896
# deceduti                                       468
# totale_casi                                   5791
# tamponi                                      21479
# Name: 324, dtype: object

# %%
DF[DF.denominazione_regione == 'Lombardia'].data
# Out:
# 9      2020-02-24 18:00:00
# 30     2020-02-25 18:00:00
# 51     2020-02-26 18:00:00
# 72     2020-02-27 18:00:00
# 93     2020-02-28 18:00:00
# 114    2020-02-29 17:00:00
# 135    2020-03-01 17:00:00
# 156    2020-03-02 18:00:00
# 177    2020-03-03 18:00:00
# 198    2020-03-04 17:00:00
# 219    2020-03-05 17:00:00
# 240    2020-03-06 17:00:00
# 261    2020-03-07 18:00:00
# 282    2020-03-08 18:00:00
# 303    2020-03-09 18:00:00
# 324    2020-03-10 18:00:00
# Name: data, dtype: object
